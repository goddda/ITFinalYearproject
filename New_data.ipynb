# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from sklearn import preprocessing
from scipy.signal import find_peaks

# %%
data_dir = os.getcwd()
data = pd.read_csv(data_dir + "/accel.csv")
data = pd.read_csv(data_dir + "/accel.csv")
i, mind, maxd = 0, 0, 0
plt.figure(0)
for a in ['accelX','accelY','accelZ']:
#     plt.figure(i)
    d = data[data['ID']==3][a]
    maxd = max(d)
    mind == min(d)
    plt.plot((d-mind)/(maxd-mind))
    i += 1
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(1)
d = data[data['type']==6]['cannula']
plt.plot(d)
peaks, _ = find_peaks(d)
plt.plot(peaks, d[peaks], "x")
# Out:
# <img src="data:image/png;base64,..." width="640">
# /afs/inf.ed.ac.uk/user/s15/s1536166/miniconda3/envs/mlp/lib/python3.7/site-packages/pandas/core/series.py:842: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
